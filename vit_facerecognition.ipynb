# %%
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
cascade_dir = cv2.data.haarcascades

cascade_file = os.path.join(cascade_dir, 'haarcascade_frontalface_default.xml')

if os.path.isfile(cascade_file):
    print("Haar cascade file found:", cascade_file)
else:
    print("Haar cascade file not found. Downloading...")
    cv2_base_url = "https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/"
    cascade_url = cv2_base_url + 'haarcascade_frontalface_default.xml'
    os.system(f"wget {cascade_url} -P {cascade_dir}")
    print("Haar cascade file downloaded successfully.")
filter_path = cascade_file
# Out:
# Haar cascade file found: /opt/conda/lib/python3.10/site-packages/cv2/data/haarcascade_frontalface_default.xml

# %%
# Function to detect faces and crop them from an image
def detect_and_crop_faces(image):
    face_cascade = cv2.CascadeClassifier(filter_path)
    faces = face_cascade.detectMultiScale(image, 1.3, 5)
    cropped_faces = []
    for (x, y, w, h) in faces:
        cropped_faces.append(image[y:y+h, x:x+w])
    return cropped_faces

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split

dataset_dir = "/kaggle/input/face-recognition-dataset/Original Images/Original Images"
cropped_dataset_dir = "/kaggle/working/CroppedImages"
train_dir = os.path.join(cropped_dataset_dir, "train")
test_dir = os.path.join(cropped_dataset_dir, "test")

os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

common_size = (128, 128)

for subdir in os.listdir(dataset_dir):
    subdir_path = os.path.join(dataset_dir, subdir)
    if os.path.isdir(subdir_path):
        train_subdir_path = os.path.join(train_dir, subdir)
        test_subdir_path = os.path.join(test_dir, subdir)
        os.makedirs(train_subdir_path, exist_ok=True)
        os.makedirs(test_subdir_path, exist_ok=True)
        image_files = [f for f in os.listdir(subdir_path) if f.endswith('.jpg')]
        for image_name in image_files:
            image_path = os.path.join(subdir_path, image_name)
            img = cv2.imread(image_path)
            faces = detect_and_crop_faces(img)
            for idx, face in enumerate(faces):
                if face is not None:
                    resized_face = cv2.resize(face, common_size)
                    if np.random.rand() < 0.9:
                        save_path = os.path.join(train_subdir_path, f"{image_name}_{idx}.jpg")
                    else:
                        save_path = os.path.join(test_subdir_path, f"{image_name}_{idx}.jpg")
                    cv2.imwrite(save_path, resized_face)
print('dataset created')
# Out:
# dataset created

# %%
gpus = tf.config.list_physical_devices('GPU')
if not gpus:
    raise RuntimeError("No GPU device found.")
    
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
train_dir = '/kaggle/working/CroppedImages/train'
test_dir = '/kaggle/working/CroppedImages/test'
generator = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.1
)
train_ds = generator.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode = "sparse",
    subset="training"  
)

val_ds = generator.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=32,
    
    class_mode = "sparse",
    subset="validation"
)

classes = list(train_ds.class_indices.keys())
print("Classes in training data:", classes)

test_ds = generator.flow_from_directory(
    test_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode = "sparse",
    subset="training"
)

test_classes = list(test_ds.class_indices.keys())
print("Classes in test data:", test_classes)
# Out:
# Found 2047 images belonging to 31 classes.
# Found 213 images belonging to 31 classes.
# Classes in training data: ['Akshay Kumar', 'Alexandra Daddario', 'Alia Bhatt', 'Amitabh Bachchan', 'Andy Samberg', 'Anushka Sharma', 'Billie Eilish', 'Brad Pitt', 'Camila Cabello', 'Charlize Theron', 'Claire Holt', 'Courtney Cox', 'Dwayne Johnson', 'Elizabeth Olsen', 'Ellen Degeneres', 'Henry Cavill', 'Hrithik Roshan', 'Hugh Jackman', 'Jessica Alba', 'Kashyap', 'Lisa Kudrow', 'Margot Robbie', 'Marmik', 'Natalie Portman', 'Priyanka Chopra', 'Robert Downey Jr', 'Roger Federer', 'Tom Cruise', 'Vijay Deverakonda', 'Virat Kohli', 'Zac Efron']
# Found 254 images belonging to 31 classes.
# Classes in test data: ['Akshay Kumar', 'Alexandra Daddario', 'Alia Bhatt', 'Amitabh Bachchan', 'Andy Samberg', 'Anushka Sharma', 'Billie Eilish', 'Brad Pitt', 'Camila Cabello', 'Charlize Theron', 'Claire Holt', 'Courtney Cox', 'Dwayne Johnson', 'Elizabeth Olsen', 'Ellen Degeneres', 'Henry Cavill', 'Hrithik Roshan', 'Hugh Jackman', 'Jessica Alba', 'Kashyap', 'Lisa Kudrow', 'Margot Robbie', 'Marmik', 'Natalie Portman', 'Priyanka Chopra', 'Robert Downey Jr', 'Roger Federer', 'Tom Cruise', 'Vijay Deverakonda', 'Virat Kohli', 'Zac Efron']

# %%
import tensorflow as tf

PATCH_SIZE = 16
IMAGE_SIZE = [128, 128, 3]  
num_patches = (IMAGE_SIZE[0] // PATCH_SIZE) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 8
mlp_head_units = [2048, 1024]
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = tf.keras.layers.Dense(units, activation=tf.nn.gelu)(x)
        x = tf.keras.layers.Dropout(dropout_rate)(x)
    return x
class Patches(tf.keras.layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = tf.keras.layers.Dense(units=projection_dim)
        self.position_embedding = tf.keras.layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
def create_vit_classifier(input_shape=(128, 128, 3)):
    inputs = tf.keras.layers.Input(shape=input_shape)
    patches = Patches(PATCH_SIZE)(inputs)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    print("Patches shape:", patches.shape)
    print("Encoded patches shape:", encoded_patches.shape)

    for _ in range(transformer_layers):
        x1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        x2 = tf.keras.layers.Add()([attention_output, encoded_patches])
        x3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        encoded_patches = tf.keras.layers.Add()([x3, x2])

    representation = tf.keras.layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = tf.keras.layers.Flatten()(representation)
    representation = tf.keras.layers.Dropout(0.5)(representation)
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    logits = tf.keras.layers.Dense(31)(features) 

    print("Logits shape:", logits.shape)

    model = tf.keras.Model(inputs=inputs, outputs=logits)
    return model

model = create_vit_classifier()
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['sparse_categorical_accuracy']
)
# Out:
# Patches shape: (None, None, 768)
# Encoded patches shape: (None, 64, 64)
# Logits shape: (None, 31)

# %%
batch_data, batch_labels = next(val_ds)
data_shape = batch_data.shape
labels_shape = batch_labels.shape

print("Data shape:", data_shape)
print("Labels shape:", labels_shape)
# Out:
# Data shape: (32, 128, 128, 3)
# Labels shape: (32,)

# %%
BATCH_SIZE = 16

history = model.fit(train_ds, epochs=100, validation_data=val_ds, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/100
#  1/64 ━━━━━━━━━━━━━━━━━━━━ 1:20:55 77s/step - loss: 6.0996 - sparse_categorical_accuracy: 0.0625
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714201441.015816     121 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 5.3227 - sparse_categorical_accuracy: 0.0349 - val_loss: 3.4467 - val_sparse_categorical_accuracy: 0.0469
# Epoch 2/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 3.5836 - sparse_categorical_accuracy: 0.0356 - val_loss: 3.4320 - val_sparse_categorical_accuracy: 0.0704
# Epoch 3/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 3.5102 - sparse_categorical_accuracy: 0.0352 - val_loss: 3.3990 - val_sparse_categorical_accuracy: 0.0610
# Epoch 4/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 3.4540 - sparse_categorical_accuracy: 0.0488 - val_loss: 3.2933 - val_sparse_categorical_accuracy: 0.0751
# Epoch 5/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 172ms/step - loss: 3.3818 - sparse_categorical_accuracy: 0.0543 - val_loss: 3.2211 - val_sparse_categorical_accuracy: 0.1080
# Epoch 6/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 3.3075 - sparse_categorical_accuracy: 0.0781 - val_loss: 3.1420 - val_sparse_categorical_accuracy: 0.1221
# Epoch 7/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 162ms/step - loss: 3.2109 - sparse_categorical_accuracy: 0.1070 - val_loss: 3.0484 - val_sparse_categorical_accuracy: 0.1221
# Epoch 8/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 3.1003 - sparse_categorical_accuracy: 0.1060 - val_loss: 2.9976 - val_sparse_categorical_accuracy: 0.1455
# Epoch 9/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 3.0898 - sparse_categorical_accuracy: 0.1102 - val_loss: 2.9441 - val_sparse_categorical_accuracy: 0.1502
# Epoch 10/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 3.1304 - sparse_categorical_accuracy: 0.1143 - val_loss: 2.9935 - val_sparse_categorical_accuracy: 0.1737
# Epoch 11/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 3.0401 - sparse_categorical_accuracy: 0.1240 - val_loss: 2.8729 - val_sparse_categorical_accuracy: 0.1549
# Epoch 12/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 2.9663 - sparse_categorical_accuracy: 0.1429 - val_loss: 2.8906 - val_sparse_categorical_accuracy: 0.1268
# Epoch 13/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 167ms/step - loss: 2.9173 - sparse_categorical_accuracy: 0.1288 - val_loss: 2.8293 - val_sparse_categorical_accuracy: 0.2019
# Epoch 14/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 2.9366 - sparse_categorical_accuracy: 0.1571 - val_loss: 2.8539 - val_sparse_categorical_accuracy: 0.1972
# Epoch 15/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 2.8227 - sparse_categorical_accuracy: 0.1746 - val_loss: 2.7654 - val_sparse_categorical_accuracy: 0.1925
# Epoch 16/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 2.8065 - sparse_categorical_accuracy: 0.1872 - val_loss: 2.7431 - val_sparse_categorical_accuracy: 0.1831
# Epoch 17/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 162ms/step - loss: 2.8498 - sparse_categorical_accuracy: 0.1787 - val_loss: 2.7780 - val_sparse_categorical_accuracy: 0.2019
# Epoch 18/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 2.7325 - sparse_categorical_accuracy: 0.2003 - val_loss: 2.7078 - val_sparse_categorical_accuracy: 0.1972
# Epoch 19/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 2.7240 - sparse_categorical_accuracy: 0.2136 - val_loss: 2.6174 - val_sparse_categorical_accuracy: 0.2113
# Epoch 20/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 2.7131 - sparse_categorical_accuracy: 0.2069 - val_loss: 2.6306 - val_sparse_categorical_accuracy: 0.1784
# Epoch 21/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 2.6953 - sparse_categorical_accuracy: 0.1933 - val_loss: 2.6180 - val_sparse_categorical_accuracy: 0.2207
# Epoch 22/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - loss: 2.5871 - sparse_categorical_accuracy: 0.2104 - val_loss: 2.5394 - val_sparse_categorical_accuracy: 0.2488
# Epoch 23/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 2.6189 - sparse_categorical_accuracy: 0.2283 - val_loss: 2.4771 - val_sparse_categorical_accuracy: 0.2770
# Epoch 24/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 2.5672 - sparse_categorical_accuracy: 0.2556 - val_loss: 2.4230 - val_sparse_categorical_accuracy: 0.2629
# Epoch 25/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 2.5066 - sparse_categorical_accuracy: 0.2345 - val_loss: 2.3731 - val_sparse_categorical_accuracy: 0.3099
# Epoch 26/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 2.4182 - sparse_categorical_accuracy: 0.2806 - val_loss: 2.4582 - val_sparse_categorical_accuracy: 0.3052
# Epoch 27/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━
100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 1.5140 - sparse_categorical_accuracy: 0.5193 - val_loss: 1.9270 - val_sparse_categorical_accuracy: 0.4460
# Epoch 47/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 1.5437 - sparse_categorical_accuracy: 0.5182 - val_loss: 1.8534 - val_sparse_categorical_accuracy: 0.4977
# Epoch 48/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 1.4386 - sparse_categorical_accuracy: 0.5488 - val_loss: 1.8387 - val_sparse_categorical_accuracy: 0.4883
# Epoch 49/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 1.4127 - sparse_categorical_accuracy: 0.5335 - val_loss: 1.7311 - val_sparse_categorical_accuracy: 0.5305
# Epoch 50/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 1.3919 - sparse_categorical_accuracy: 0.5612 - val_loss: 1.8441 - val_sparse_categorical_accuracy: 0.4977
# Epoch 51/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 1.3319 - sparse_categorical_accuracy: 0.5858 - val_loss: 1.7140 - val_sparse_categorical_accuracy: 0.5540
# Epoch 52/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 1.3873 - sparse_categorical_accuracy: 0.5671 - val_loss: 1.7597 - val_sparse_categorical_accuracy: 0.5634
# Epoch 53/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 1.1671 - sparse_categorical_accuracy: 0.6212 - val_loss: 1.8231 - val_sparse_categorical_accuracy: 0.5070
# Epoch 54/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - loss: 1.2985 - sparse_categorical_accuracy: 0.5831 - val_loss: 1.7665 - val_sparse_categorical_accuracy: 0.6009
# Epoch 55/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 1.1216 - sparse_categorical_accuracy: 0.6341 - val_loss: 1.7231 - val_sparse_categorical_accuracy: 0.5352
# Epoch 56/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 1.1820 - sparse_categorical_accuracy: 0.6249 - val_loss: 1.9331 - val_sparse_categorical_accuracy: 0.4977
# Epoch 57/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 1.0971 - sparse_categorical_accuracy: 0.6455 - val_loss: 1.9399 - val_sparse_categorical_accuracy: 0.5258
# Epoch 58/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 1.0437 - sparse_categorical_accuracy: 0.6678 - val_loss: 1.7852 - val_sparse_categorical_accuracy: 0.5446
# Epoch 59/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 163ms/step - loss: 1.0593 - sparse_categorical_accuracy: 0.6390 - val_loss: 1.7853 - val_sparse_categorical_accuracy: 0.5258
# Epoch 60/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - loss: 0.9932 - sparse_categorical_accuracy: 0.6733 - val_loss: 1.9689 - val_sparse_categorical_accuracy: 0.5399
# Epoch 61/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 167ms/step - loss: 0.9619 - sparse_categorical_accuracy: 0.6789 - val_loss: 1.8055 - val_sparse_categorical_accuracy: 0.5258
# Epoch 62/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step - loss: 0.9201 - sparse_categorical_accuracy: 0.7003 - val_loss: 1.8924 - val_sparse_categorical_accuracy: 0.5540
# Epoch 63/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 0.9170 - sparse_categorical_accuracy: 0.6948 - val_loss: 1.7932 - val_sparse_categorical_accuracy: 0.5728
# Epoch 64/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 163ms/step - loss: 0.9100 - sparse_categorical_accuracy: 0.7050 - val_loss: 1.8318 - val_sparse_categorical_accuracy: 0.5305
# Epoch 65/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━
100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 0.5520 - sparse_categorical_accuracy: 0.8204 - val_loss: 1.9650 - val_sparse_categorical_accuracy: 0.5775
# Epoch 85/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.5429 - sparse_categorical_accuracy: 0.8333 - val_loss: 1.6577 - val_sparse_categorical_accuracy: 0.6573
# Epoch 86/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 0.5074 - sparse_categorical_accuracy: 0.8367 - val_loss: 1.8007 - val_sparse_categorical_accuracy: 0.5869
# Epoch 87/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - loss: 0.5479 - sparse_categorical_accuracy: 0.8244 - val_loss: 1.6272 - val_sparse_categorical_accuracy: 0.5962
# Epoch 88/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 0.5557 - sparse_categorical_accuracy: 0.8054 - val_loss: 1.8330 - val_sparse_categorical_accuracy: 0.6009
# Epoch 89/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - loss: 0.5107 - sparse_categorical_accuracy: 0.8551 - val_loss: 1.8018 - val_sparse_categorical_accuracy: 0.6009
# Epoch 90/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.4997 - sparse_categorical_accuracy: 0.8389 - val_loss: 2.0440 - val_sparse_categorical_accuracy: 0.5728
# Epoch 91/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - loss: 0.4428 - sparse_categorical_accuracy: 0.8571 - val_loss: 1.8691 - val_sparse_categorical_accuracy: 0.5352
# Epoch 92/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 162ms/step - loss: 0.5016 - sparse_categorical_accuracy: 0.8413 - val_loss: 1.8214 - val_sparse_categorical_accuracy: 0.6009
# Epoch 93/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 169ms/step - loss: 0.5045 - sparse_categorical_accuracy: 0.8401 - val_loss: 1.8666 - val_sparse_categorical_accuracy: 0.5962
# Epoch 94/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.4751 - sparse_categorical_accuracy: 0.8398 - val_loss: 1.8509 - val_sparse_categorical_accuracy: 0.6291
# Epoch 95/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - loss: 0.4733 - sparse_categorical_accuracy: 0.8476 - val_loss: 1.8595 - val_sparse_categorical_accuracy: 0.6056
# Epoch 96/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.4117 - sparse_categorical_accuracy: 0.8652 - val_loss: 1.9809 - val_sparse_categorical_accuracy: 0.5446
# Epoch 97/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.4607 - sparse_categorical_accuracy: 0.8399 - val_loss: 1.9652 - val_sparse_categorical_accuracy: 0.5869
# Epoch 98/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.4144 - sparse_categorical_accuracy: 0.8720 - val_loss: 2.1156 - val_sparse_categorical_accuracy: 0.5915
# Epoch 99/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 12s 166ms/step - loss: 0.4737 - sparse_categorical_accuracy: 0.8463 - val_loss: 1.8229 - val_sparse_categorical_accuracy: 0.5962
# Epoch 100/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - loss: 0.4164 - sparse_categorical_accuracy: 0.8655 - val_loss: 1.8818 - val_sparse_categorical_accuracy: 0.5869

# %%
train_loss, train_accuracy = model.evaluate(train_ds)
print(f"Training Accuracy: {train_accuracy*100: .2f}")
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 13s 198ms/step - loss: 0.1008 - sparse_categorical_accuracy: 0.9708
# Training Accuracy:  97.61

# %%
validation_loss, validation_accuracy = model.evaluate(val_ds)
print(f"Validation Accuracy: {validation_accuracy*100: .2f}")
# Out:
# Validation Accuracy:  76.27
